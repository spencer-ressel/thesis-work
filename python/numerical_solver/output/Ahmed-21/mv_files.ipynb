# %%
import os
import numpy as np
from glob import glob

# %%
os.chdir('/home/disk/eos7/sressel/research/thesis-work/python/numerical_solver/output/Ahmed-21/')

# %%
all_directories = glob('*')

for directory in all_directories[-1:]:
    os.system(f"mkdir {directory}/Kelvin-wave_initial-condition")
    os.system(f"mkdir {directory}/Rossby-wave_initial-condition")
    print(f"\n")
    # print(glob(f"{directory}/*Kelvin*"))
    # print(f"\n")

# %%
for directory in all_directories[-1:]:
    all_files = glob(f"{directory}/*Kelvin*")
    for file in all_files[1:]:
        os.system(f"mv {file} {directory}/Kelvin-wave_initial-condition")
        print(f"\n")
# Out:
# mv: cannot move 'epst-step-y=0.50_epsq-step-y=0.17_r=0.2_nx=1.0_ny=1.00_exponential-base-state_diffusive-damped-moist-coupled-simulation/Kelvin-wave_initial-condition' to a subdirectory of itself, 'epst-step-y=0.50_epsq-step-y=0.17_r=0.2_nx=1.0_ny=1.00_exponential-base-state_diffusive-damped-moist-coupled-simulation/Kelvin-wave_initial-condition/Kelvin-wave_initial-condition'
