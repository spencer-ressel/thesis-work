# %%
# import glob
# import os
# variable_names = ['Z3']
# experiments_list = ['-4K', '0K', '4K']
# experiment_locations = ['SST_AQP3_Qobs_27_-4K_3h_10y', 'SST_AQP3_Qobs_27_3h_20y', 'SST_AQP3_Qobs_27_4K_3h_10y']
# for location, experiment in zip(experiment_locations, experiments_list):
#     print(f"Experiment: {experiment}")
#     for variable in variable_names:
#         print(f"Variable: {variable}")
#         os.system(
#             f"module load cdo;"
#             + f" cdo -s -O -daymean -shifttime,-10hour -shifttime,-30minute -mergetime -apply,-selname,{variable} [ /glade/campaign/univ/uwas0114/{location}/atm/hist/*h1*.nc ] /glade/derecho/scratch/sressel/{experiment}/daily_model-level_data/SST_AQP3_Qobs_27_{experiment}_1D_20y_{variable}.nc;"
#         )
# print("Finished")

# %%
import glob
import os
experiments_list = ['-4K', '0K', '4K']
for variable in ['CLDICE']:
    print(f"Variable: {variable}")
    print(f"{'-'*40}")
    for experiment in experiments_list:
        print(f"{f'{experiment}...':<{40-1}}", end='')
        os.system(
            f"module load cdo;"
            + f" cdo -O -shifttime,-10hour -shifttime,-30minute "
            + f"/glade/campaign/univ/uwas0152/post_processed_data/{experiment}/daily_model-level_data/SST_AQP3_Qobs_27_{experiment}_1D_{variable}.nc "
            + f"/glade/campaign/univ/uwas0152/post_processed_data/{experiment}/daily_model-level_data/SST_AQP3_Qobs_27_{experiment}_1D_{variable}_shifted.nc"
        )
        print(rf"{'✔':>1}")

print(f"{'='*40}")
print("Finished")
# Out:
# Variable: CLDICE
# ----------------------------------------
# -4K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - hyam
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - hybm
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - P0
# HDF5-DIAG: Error detected in HDF5 (1.14.6) thread 1:
#   #000: /glade/derecho/scratch/csgteam/temp/spack/derecho/25.10/builds/spack-stage-hdf5-1.14.6-rybfelndtxlk65xgkaefx4urt45ykq2t/spack-src/src/H5F.c line 496 in H5Fis_accessible(): unable to determine if file is accessible as HDF5
#     major: File accessibility
#     minor: Not an HDF5 file
#   #001: /glade/derecho/scratch/csgteam/temp/spack/derecho/25.10/builds/spack-stage-hdf5-1.14.6-rybfelndtxlk65xgkaefx4urt45ykq2t/spack-src/src/H5VLcallback.c line 3913 in H5VL_file_specific(): file specific failed
#     major: Virtual Object Layer
#     minor: Can't operate on object
# ...

# %%
# import glob
# import xarray as xr
# files_list = sorted(glob.glob("/glade/campaign/univ/uwas0114/SST_AQP3_Qobs_27_4K_3h_10y/atm/hist/*h1*.nc"))
# xr.open_dataset(files_list[0])
import xarray as xr
xr.open_dataset(f"/glade/campaign/univ/uwas0152/post_processed_data/{experiment}/daily_model-level_data/SST_AQP3_Qobs_27_{experiment}_1D_{variable}.nc")
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:  (lat: 42, lon: 144, lev: 32, time: 3650)
# Coordinates:
#   * lat      (lat) float64 336B -38.84 -36.95 -35.05 ... 35.05 36.95 38.84
#   * lon      (lon) float64 1kB 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lev      (lev) float64 256B 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * time     (time) object 29kB 0003-01-04 00:00:00 ... 0013-01-03 00:00:00
# Data variables:
#     CLDICE   (time, lev, lat, lon) float32 3GB ...
