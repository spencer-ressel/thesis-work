# %%
# import glob
# import os
# variable_names = ['Z3']
# experiments_list = ['-4K', '0K', '4K']
# experiment_locations = ['SST_AQP3_Qobs_27_-4K_3h_10y', 'SST_AQP3_Qobs_27_3h_20y', 'SST_AQP3_Qobs_27_4K_3h_10y']
# for location, experiment in zip(experiment_locations, experiments_list):
#     print(f"Experiment: {experiment}")
#     for variable in variable_names:
#         print(f"Variable: {variable}")
#         os.system(
#             f"module load cdo;"
#             + f" cdo -s -O -daymean -shifttime,-10hour -shifttime,-30minute -mergetime -apply,-selname,{variable} [ /glade/campaign/univ/uwas0114/{location}/atm/hist/*h1*.nc ] /glade/derecho/scratch/sressel/{experiment}/daily_model-level_data/SST_AQP3_Qobs_27_{experiment}_1D_20y_{variable}.nc;"
#         )
# print("Finished")

# %%
# for variable in ['T', 'Q', 'Z3', 'PS']:
#     print(f"Variable: {variable}")
#     print(f"{'-'*40}")
#     for experiment in experiments_list:
#         print(f"{f'{experiment}...':<{40-1}}", end='')
#         os.system(
#             f"module load cdo;"
#             + f" cdo -O -shifttime,-10hour -shifttime,-30minute "
#             + f"/glade/derecho/scratch/sressel/{experiment}/daily_model-level_data/SST_AQP3_Qobs_27_{experiment}_1D_20y_{variable}.nc "
#             + f"/glade/derecho/scratch/sressel/{experiment}/daily_model-level_data/SST_AQP3_Qobs_27_{experiment}_1D_20y_{variable}_shifted.nc"
#         )
#         print(rf"{'✔':>1}")

# print(f"{'='*40}")
# print("Finished")
# Out:
# Variable: T
# ----------------------------------------
# -4K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# 0K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# 4K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# Variable: Q
# ----------------------------------------
# -4K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# 0K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# 4K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# Variable: Z3
# ----------------------------------------
# -4K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# 0K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# 4K...
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - ap_bnds
# cdi  warning (scan_hybrid_formulaterms): NetCDF: Variable not found - b_bnds
# ✔
# Variable: PS
# ----------------------------------------
# -4K...                                 ✔
# 0K...                                  ✔
# 4K...                                  ✔
# ========================================
# Finished

# %%
import glob
import xarray as xr
files_list = sorted(glob.glob("/glade/campaign/univ/uwas0114/SST_AQP3_Qobs_27_4K_3h_10y/atm/hist/*h1*.nc"))
xr.open_dataset(files_list[0])
# Out:
# <xarray.Dataset> Size: 734MB
# Dimensions:       (lat: 96, lon: 144, lev: 32, ilev: 33, time: 31, nbnd: 2)
# Coordinates:
#   * lat           (lat) float64 768B -90.0 -88.11 -86.21 ... 86.21 88.11 90.0
#   * lon           (lon) float64 1kB 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#   * lev           (lev) float64 256B 3.643 7.595 14.36 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 264B 2.255 5.032 10.16 ... 967.5 985.1 1e+03
#   * time          (time) object 248B 0003-01-03 09:00:00 ... 0003-01-07 03:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/50)
#     gw            (lat) float64 768B ...
#     hyam          (lev) float64 256B ...
#     hybm          (lev) float64 256B ...
#     P0            float64 8B ...
#     hyai          (ilev) float64 264B ...
#     hybi          (ilev) float64 264B ...
#     ...            ...
#     SHFLX         (time, lat, lon) float32 2MB ...
#     T             (time, lev, lat, lon) float32 55MB ...
#     TMQ           (time, lat, lon) float32 2MB ...
#     U             (time, lev, lat, lon) float32 55MB ...
#     V             (time, lev, lat, lon) float32 55MB ...
#     Z3            (time, lev, lat, lon) float32 55MB ...
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              SST_AQP3_Qobs_27_4K_3h_20y
#     logname:           muting
#     host:              cheyenne4
#     initial_file:      /glade/p/cesmdata/cseg/inputdata/atm/cam/inic/fv/aqua_...
#     topography_file:   bnd_topo
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     time_period_freq:  hour_3
