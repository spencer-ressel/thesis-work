# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
moisture = xr.load_dataset("/home/disk/eos7/sressel/research/data/ECMWF/ERA5/era5_q.nc")
moisture
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 14245, lev: 27, lat: 25, lon: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2018-12-31
#   * lev      (lev) float64 1e+03 975.0 950.0 925.0 ... 175.0 150.0 125.0 100.0
#   * lat      (lat) float32 -30.0 -27.5 -25.0 -22.5 -20.0 ... 22.5 25.0 27.5 30.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
# Data variables:
#     x        (time, lev, lat, lon) float32 0.009597 0.009501 ... 2.366e-06
# Attributes:
#     creation_date:  Fri May 29 10:59:23 PDT 2020
#     title:          era5_1000_100hPa_30S_30N

# %%
mixing_ratio = moisture/(1-moisture)

# %%
mixing_ratio
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 14245, lev: 27, lat: 25, lon: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2018-12-31
#   * lev      (lev) float64 1e+03 975.0 950.0 925.0 ... 175.0 150.0 125.0 100.0
#   * lat      (lat) float32 -30.0 -27.5 -25.0 -22.5 -20.0 ... 22.5 25.0 27.5 30.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
# Data variables:
#     x        (time, lev, lat, lon) float32 0.00969 0.009592 ... 2.366e-06
