# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

data = xr.open_dataset('/glade/u/home/sressel/thesis-work/python/neuralGCM_analysis/multi_day_2018-01-01_deterministic_cf.nc')

# %%
data
# Out:
# <xarray.Dataset> Size: 68MB
# Dimensions:                              (longitude: 256, latitude: 128,
#                                           level: 37, time: 2)
# Coordinates:
#   * longitude                            (longitude) float64 2kB 0.0 ... 358.6
#   * latitude                             (latitude) float64 1kB -88.93 ... 88.93
#   * level                                (level) int32 148B 1 2 3 ... 975 1000
#   * time                                 (time) int32 8B 0 1
# Data variables:
#     v_component_of_wind                  (time, level, longitude, latitude) float32 10MB ...
#     geopotential                         (time, level, longitude, latitude) float32 10MB ...
#     specific_cloud_liquid_water_content  (time, level, longitude, latitude) float32 10MB ...
#     specific_humidity                    (time, level, longitude, latitude) float32 10MB ...
#     temperature                          (time, level, longitude, latitude) float32 10MB ...
# ...

# %%
data['geopotential'].isel(time=0).sel(level=850).plot(x='longitude')
plt.figure()
data['geopotential'].isel(time=1).sel(level=850).plot(x='longitude')

# %%
np.min(data['geopotential'].isel(time=1).sel(level=850) - data['geopotential'].isel(time=0).sel(level=850))
# Out:
# <xarray.DataArray 'geopotential' ()> Size: 8B
# array(0.)
# Coordinates:
#     level    int32 4B 850
#     time     int32 4B 0
